# %%
#import Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import statsmodels.formula.api as smf

# %%
#import dataset
dataset=pd.read_csv("Salary_Data.csv")
dataset
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
dataset.dtypes
# Out:
# YearsExperience    float64
# Salary             float64
# dtype: object

# %%
dataset.shape
# Out:
# (30, 2)

# %%
#checking for missing values
dataset.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
#Checking correlation between the dependent and independent variable
#Years Experience is independent variable while salary is dependent variables
dataset.corr()
# Out:
#                  YearsExperience    Salary
# YearsExperience         1.000000  0.978242
# Salary                  0.978242  1.000000

# %%
sns.displot(dataset["Salary"])

# %%
sns.displot(dataset["YearsExperience"])

# %%
#Checking relation between dependent and independent variables
sns.scatterplot(x="YearsExperience",y="Salary",data=dataset)
# Out:
# <Axes: xlabel='YearsExperience', ylabel='Salary'>

# %%
dataset=dataset.rename({"YearsExperience":"yrsexp"},axis=1)
dataset
# Out:
#     yrsexp    Salary
# 0      1.1   39343.0
# 1      1.3   46205.0
# 2      1.5   37731.0
# 3      2.0   43525.0
# 4      2.2   39891.0
# 5      2.9   56642.0
# 6      3.0   60150.0
# 7      3.2   54445.0
# 8      3.2   64445.0
# 9      3.7   57189.0
# 10     3.9   63218.0
# 11     4.0   55794.0
# 12     4.0   56957.0
# 13     4.1   57081.0
# 14     4.5   61111.0
# 15     4.9   67938.0
# 16     5.1   66029.0
# 17     5.3   83088.0
# 18     5.9   81363.0
# 19     6.0   93940.0
# 20     6.8   91738.0
# 21     7.1   98273.0
# 22     7.9  101302.0
# 23     8.2  113812.0
# 24     8.7  109431.0
# 25     9.0  105582.0
# 26     9.5  116969.0
# 27     9.6  112635.0
# 28    10.3  122391.0
# 29    10.5  121872.0

# %%
sns.regplot(x=dataset['yrsexp'],y=dataset['Salary'])
# Out:
# <Axes: xlabel='yrsexp', ylabel='Salary'>

# %% [markdown]
# # Building the model

# %%
model=smf.ols("Salary~yrsexp",data=dataset).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Salary   R-squared:                       0.957
# Model:                            OLS   Adj. R-squared:                  0.955
# Method:                 Least Squares   F-statistic:                     622.5
# Date:                Mon, 10 Jul 2023   Prob (F-statistic):           1.14e-20
# Time:                        17:36:43   Log-Likelihood:                -301.44
# No. Observations:                  30   AIC:                             606.9
# Df Residuals:                      28   BIC:                             609.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   2.579e+04   2273.053     11.347      0.000    2.11e+04    3.04e+04
# ...

# %%
model.params
# Out:
# Intercept    25792.200199
# yrsexp        9449.962321
# dtype: float64

# %%
model2=smf.ols("np.sqrt(Salary)~yrsexp",data=dataset).fit()
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:        np.sqrt(Salary)   R-squared:                       0.950
# Model:                            OLS   Adj. R-squared:                  0.948
# Method:                 Least Squares   F-statistic:                     530.2
# Date:                Mon, 10 Jul 2023   Prob (F-statistic):           9.78e-20
# Time:                        17:43:28   Log-Likelihood:                -114.33
# No. Observations:                  30   AIC:                             232.7
# Df Residuals:                      28   BIC:                             235.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    180.7002      4.446     40.646      0.000     171.594     189.807
# ...

# %%
model3=smf.ols("Salary~np.sqrt(yrsexp)",data=dataset).fit()
model3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Salary   R-squared:                       0.931
# Model:                            OLS   Adj. R-squared:                  0.929
# Method:                 Least Squares   F-statistic:                     377.8
# Date:                Mon, 10 Jul 2023   Prob (F-statistic):           8.57e-18
# Time:                        17:43:28   Log-Likelihood:                -308.52
# No. Observations:                  30   AIC:                             621.0
# Df Residuals:                      28   BIC:                             623.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
dataset["yrsexp_Sq"]=dataset.yrsexp**2
model_quad=smf.ols("np.log(Salary)~yrsexp+yrsexp_Sq",data=dataset).fit()
#model_quad.summary()
model_quad.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:         np.log(Salary)   R-squared:                       0.949
# Model:                            OLS   Adj. R-squared:                  0.945
# Method:                 Least Squares   F-statistic:                     249.2
# Date:                Mon, 10 Jul 2023   Prob (F-statistic):           3.95e-18
# Time:                        17:49:03   Log-Likelihood:                 32.391
# No. Observations:                  30   AIC:                            -58.78
# Df Residuals:                      27   BIC:                            -54.58
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     10.3369      0.067    154.368      0.000      10.199      10.474
# ...

# %% [markdown]
# # We can conclude that model 1 is the best model as it gives the highest R-squared values.
